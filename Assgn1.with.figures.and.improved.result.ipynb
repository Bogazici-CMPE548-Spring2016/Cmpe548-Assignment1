# %%
__author__ = 'demetyalman'
# %matplotlib inline
import matplotlib.pyplot as plt
import random
import math

# Create N random samples in (0,1)
N = 1000

# we need to generate samples for R and Theta first
R = []
Theta = []

for i in range(N):
    R.append(math.sqrt(random.uniform(0,1)))

for i in range(N):
    # since theta ~ (0, 2*pi)
    Theta.append(random.uniform(0, 2*math.pi))

# Now, we need to obtain polar coordinates (x,y)
# x = r*cos(theta)  and  y = r*sin(theta)
x = []
y = []

for i in range(N):
    x.append(R[i] * math.cos(Theta[i]))
    y.append(R[i] * math.sin(Theta[i]))


#plot answer of the 1st question
plt.plot(x, y,'b*')
plt.axis([-1.5, 1.5, -1.5, 1.5])
plt.xlabel('x')
plt.ylabel('y')
plt.show()


p = [1.5, 0.7, 0.7]

# p-norm
def p_norm(x, y, p):
    return math.pow( math.pow(math.fabs(x),p) + math.pow(math.fabs(y),p), (1/p) )

# when p=1, p-norm gives a rotates square
# based on it, I used a proposal which is similar to 1-norm
def new_proposal(x, y, p):
    return math.pow( math.fabs(x) + math.fabs(y), (1/p) )

# inequality p_norm <= 1
def acceptance_condition(cond):
    if cond <= 1:
        return 1
    else:
        return 0
# to keep accepted samples
accepted_x = []
accepted_y = []

# for two different  p values and one more p=0.7 for an improved result
accepted_x.append([])
accepted_x.append([])
accepted_x.append([])

accepted_y.append([])
accepted_y.append([])
accepted_y.append([])

# for each p value, obtain accepted x and y values which fulfill the condition
for i in range(len(p)):
    for j in range(len(x)):
        if i<2:
            if acceptance_condition(p_norm(x[j], y[j], p[i])) == 1 :
                accepted_x[i].append(x[j])
                accepted_y[i].append(y[j])
        else:
            if acceptance_condition(new_proposal(x[j], y[j], p[i])) == 1 :
                accepted_x[i].append(x[j])
                accepted_y[i].append(y[j])

# plot
for i in range(len(accepted_x)):
    plt.plot(accepted_x[i],accepted_y[i],'ro')
    plt.axis([-1.5, 1.5, -1.5, 1.5])
    plt.show()

# acceptance rate
acceptance_rate = [0.0,0.0,0.0]


for i in range(len(accepted_x)):
    # number of accepted samples / total number of samples
    acceptance_rate[i] = float(len(accepted_x[i])) / len(x)
    print "Acceptance rate is %.5f when p=%.1f" %(acceptance_rate[i], p[i])
# Out:
# /home/demetyalman/anaconda2/lib/python2.7/site-packages/matplotlib/font_manager.py:273: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   warnings.warn('Matplotlib is building the font cache using fc-list. This may take a moment.')
# Acceptance rate is 0.86600 when p=1.5
# Acceptance rate is 0.42500 when p=0.7
# Acceptance rate is 0.65400 when p=0.7
